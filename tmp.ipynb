# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("sentimentdataset_clean.xlsx")

# %%
df
# Out:
#       ID                                               Text  \
# 0      0              Enjoying a beautiful day at the park!
# 1      1                 Traffic was terrible this morning.
# 2      2                Just finished an amazing workout! 💪
# 3      3        Excited about the upcoming weekend getaway!
# 4      4        Trying out a new recipe for dinner tonight.
# ..   ...                                                ...
# 702  702  Collaborating on a science project that receiv...
# 703  703  Attending a surprise birthday party organized ...
# 704  704  Successfully fundraising for a school charity ...
# 705  705  Participating in a multicultural festival, cel...
# 706  706  Organizing a virtual talent show during challe...
#
#     Specific_Sentiment General_Sentiment           Timestamp  \
# 0             Positive     Joy/Happiness 2023-01-15 12:30:00
# 1             Negative           Sadness 2023-01-15 08:45:00
# ...

# %%
mapping = dict()

# %%
for _, row in df.iterrows():
    mapping[row['General_Sentiment']] = []

for _, row in df.iterrows():
    if row['Specific_Sentiment'] not in mapping[row['General_Sentiment']]:
        mapping[row['General_Sentiment']].append(row['Specific_Sentiment'])

# %%
for key, value in mapping.items():
    formatted_list = ', '.join(f'"{item.lower()}"' for item in value)

    print(f'    elif sentiment in [{formatted_list}]:')
    print(f'        return "{key}"')
# Out:
#     elif sentiment in ["positive", "happiness", "joy", "amusement", "enjoyment", "excitement", "elation", "euphoria", "gratitude", "hope", "empowerment", "enthusiasm", "fulfillment", "nostalgia", "ambivalence", "zest", "proud", "playful", "free-spirited", "inspired", "confident", "overjoyed", "joyfulreunion", "satisfaction", "blessed", "accomplishment", "optimism", "playfuljoy", "dreamchaser", "elegance", "creativity", "radiance", "rejuvenation", "festivejoy", "innerjourney", "freedom", "dazzle", "adrenaline", "artisticburst", "culinaryodyssey", "immersion", "spark", "positivity", "success", "grandeur", "emotion", "energy", "celebration", "charm", "ecstasy", "colorful", "hypnotic", "iconic", "journey", "engagement", "triumph", "breakthrough", "joy in baking", "vibrancy", "mesmerizing", "thrilling journey", "creative inspiration", "relief", "happy"]:
#         return "Joy/Happiness"
# ...

# %%
# mapping
